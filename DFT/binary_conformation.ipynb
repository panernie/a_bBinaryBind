# %%
import sys
import os
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import PandasTools
from rdkit.Chem import Draw
from rdkit import DataStructs
from rdkit.ML.Descriptors import MoleculeDescriptors
from rdkit.Chem import rdMolTransforms
from tqdm import tqdm
import openpyxl
import codecs

# %%
df = pd.read_excel("data.xlsx")

# %%
smiles = df.smiles
names = df.Names

# %%
names = [name.replace(" ", "") for name in names]

# %%
# 定义一个函数来进行结构优化并保存为XYZ文件
def optimize_and_save_xyz(smiles, file_name):
    mol = Chem.MolFromSmiles(smiles)
    mol = Chem.AddHs(mol)
    AllChem.EmbedMolecule(mol, randomSeed=42)
    AllChem.MMFFOptimizeMoleculeConfs(mol, mmffVariant="MMFF94s")
    total_atoms = mol.GetNumAtoms()

    # 保存为XYZ文件
    conf = mol.GetConformer()
    with open(file_name, 'w') as f:
        f.write(f"{mol.GetNumAtoms()}\n")
        f.write("\n")
        for atom in mol.GetAtoms():
            pos = conf.GetAtomPosition(atom.GetIdx())
            f.write(f"{atom.GetSymbol():<2} {pos.x:.5f} {pos.y:.5f} {pos.z:.5f}\n")
            #f.write(f"{atom.GetSymbol()} {pos.x} {pos.y} {pos.z}\n")
    return total_atoms

# %%
def create_folder(folder):
    if not os.path.exists(folder):
        os.makedirs(folder)
        print(f"{folder} created!")
    else:
        print(f"{folder} already exists!")

# %%
create_folder("AAAA")
create_folder("BBBB")
# Out:
# AAAA already exists!
# BBBB already exists!

# %%
import shutil
cu_path = os.getcwd()
mol_names= []
mol_nums=[]
for smiles, file_name in zip(smiles, names):
    if "moa" in file_name:
        print(file_name)
        file_name_with_extension = file_name + ".xyz"
        total_atoms=optimize_and_save_xyz(smiles, file_name_with_extension)
        file_path = os.path.join(cu_path,f"{file_name}.xyz")
        shutil.move(file_path,os.path.join(cu_path,"AAAA"))
        mol_names.append(file_name)
        mol_nums.append(int(total_atoms))
    if "mob" in file_name:
        print(file_name)
        file_name_with_extension = file_name + ".xyz"
        total_atoms=optimize_and_save_xyz(smiles, file_name_with_extension)
        file_path = os.path.join(cu_path,f"{file_name}.xyz")
        shutil.move(file_path,os.path.join(cu_path,"BBBB"))
        mol_names.append(file_name)
        mol_nums.append(int(total_atoms))
# Out:
# moa1
# moa2
# moa3
# moa4
# moa5
# moa6
# moa7
# moa8
# moa9
# moa10
# moa11
# moa12
# moa13
# moa14
# moa15
# moa16
# moa17
# moa18
# moa19
# moa20
# moa21
# mob1
# mob2
# mob3
# mob4
# mob5
# mob6
# mob7
# mob8
# mob9
# mob10
# mob11
# mob12
# mob13
# mob14
# mob15
# mob16
# mob17
# mob18
# mob19
# mob20
# mob21

# %%
atom_num_name = pd.DataFrame(np.array([mol_names,mol_nums]).T,columns=["names","atom_num"])
atom_num_name.to_excel("atom_num_name.xlsx",index=None)

# %%
atom_num_name.head(22)
# Out:
#     names atom_num
# 0    moa1       43
# 1    moa2       42
# 2    moa3       41
# 3    moa4       52
# 4    moa5       43
# 5    moa6       68
# 6    moa7       66
# 7    moa8       34
# 8    moa9       48
# 9   moa10       52
# 10  moa11       35
# 11  moa12       41
# 12  moa13       77
# 13  moa14       74
# 14  moa15       50
# 15  moa16       51
# 16  moa17       69
# 17  moa18       59
# 18  moa19       72
# 19  moa20       67
# 20  moa21       74
# 21   mob1       36

# %% [markdown]
# # 读取指定路径下面的化合物文件名称

# %%
def get_file_names_in_directory(path):
    files = []
    file_names =[]
    for file in os.listdir(path):
        file_name = file.split(".")[0]
        file_names.append(file_name)
        if os.path.isfile(os.path.join(path, file)):
            files.append(os.path.join(path, file))
    return files,file_names

# %%
path = os.getcwd()
# 指定路径
AAA_directory_path = f"{path}/AAAA"
# 获取指定路径下的文件名称
AAA_file_paths,AAA_names = get_file_names_in_directory(AAA_directory_path)

BBB_directory_path = f"{path}/BBBB"
# 获取指定路径下的文件名称
BBB_file_paths,BBB_names = get_file_names_in_directory(BBB_directory_path)

# %%
AAA_file_paths
# Out:
# ['/home/cptd/Documents/Molclus/fangbo/AAAA/moa1.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa2.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa3.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa4.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa5.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa6.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa7.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa8.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa9.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa10.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa11.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa12.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa13.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa14.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa15.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa16.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa17.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa18.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa19.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa20.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/AAAA/moa21.xyz']

# %%
BBB_file_paths
# Out:
# ['/home/cptd/Documents/Molclus/fangbo/BBBB/mob1.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob2.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob3.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob4.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob5.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob6.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob7.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob8.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob9.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob10.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob11.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob12.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob13.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob14.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob15.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob16.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob17.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob18.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob19.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob20.xyz',
#  '/home/cptd/Documents/Molclus/fangbo/BBBB/mob21.xyz']

# %% [markdown]
# # 读取ini文件，并替换和修改

# %%
def replace_ini_lines(input_file, output_file, aaa_name,bbb_name):
    with open(input_file, 'r') as f:
        lines = f.readlines()
    # 替换第12行和第14行的内容
    lines[11] = f'{aaa_name}\n'
    lines[13] = f'{bbb_name}\n'
    with open(output_file, 'w') as f:
        f.writelines(lines)

# %%
import subprocess
import os
import shutil
destination_folder = 'genmer_mol'
try:
    os.mkdir(destination_folder)
except:
    pass
destination_file_path=os.path.join(path, destination_folder)
# 输入和输出文件名
input_ini_file = 'genmer.ini'
output_ini_file = 'genmer.ini'
# 替换特定行的内容并保存为新的INI文件
for i in range(len(AAA_file_paths)):
    for j in range(len(BBB_file_paths)):
        replace_ini_lines(input_ini_file, output_ini_file,AAA_file_paths[i],BBB_file_paths[j])
        subprocess.run("/home/cptd/Documents/Molclus//genmer", shell=True)
        generated_file = "traj.xyz"
        new_file_name = f"{AAA_names[i]}_{BBB_names[j]}.xyz"
        # 重命名生成的文件
        if os.path.exists(generated_file):
            os.rename(generated_file, new_file_name)
            shutil.move(new_file_name, destination_file_path)
            print(f"文件已重命名为 {new_file_name}")
        else:
            print("生成的文件不存在或无法访问")
# Out:
# 文件已重命名为 moa1_mob1.xyz
# 文件已重命名为 moa1_mob2.xyz
# 文件已重命名为 moa1_mob3.xyz
# 文件已重命名为 moa1_mob4.xyz
# 文件已重命名为 moa1_mob5.xyz
# 文件已重命名为 moa1_mob6.xyz
# 文件已重命名为 moa1_mob7.xyz
# 文件已重命名为 moa1_mob8.xyz
# 文件已重命名为 moa1_mob9.xyz
# 文件已重命名为 moa1_mob10.xyz
# 文件已重命名为 moa1_mob11.xyz
# 文件已重命名为 moa1_mob12.xyz
# 文件已重命名为 moa1_mob13.xyz
# 文件已重命名为 moa1_mob14.xyz
# 文件已重命名为 moa1_mob15.xyz
# 文件已重命名为 moa1_mob16.xyz
# 文件已重命名为 moa1_mob17.xyz
# 文件已重命名为 moa1_mob18.xyz
# 文件已重命名为 moa1_mob19.xyz
# 文件已重命名为 moa1_mob20.xyz
# 文件已重命名为 moa1_mob21.xyz
# 文件已重命名为 moa2_mob1.xyz
# 文件已重命名为 moa2_mob2.xyz
# 文件已重命名为 moa2_mob3.xyz
# 文件已重命名为 moa2_mob4.xyz
# 文件已重命名为 moa2_mob5.xyz
# 文件已重命名为 moa2_mob6.xyz
# 文件已重命名为 moa2_mob7.xyz
# 文件已重命名为 moa2_mob8.xyz
# 文件已重命名为 moa2_mob9.xyz
# 文件已重命名为 moa2_mob10.xyz
# 文件已重命名为 moa2_mob11.xyz
# 文件已重命名为 moa2_mob12.xyz
# 文件已重命名为 moa2_mob13.xyz
# 文件已重命名为 moa2_mob14.xyz
# 文件已重命名为 moa2_mob15.xyz
# 文件已重命名为 moa2_mob16.xyz
# 文件已重命名为 moa2_mob17.xyz
# 文件已重命名为 moa2_mob18.xyz
# 文件已重命名为 moa2_mob19.xyz
# 文件已重命名为 moa2_mob20.xyz
# 文件已重命名为 moa2_mob21.xyz
# 文件已重命名为 moa3_mob1.xyz
# 文件已重命名为 moa3_mob2.xyz
# 文件已重命名为 moa3_mob3.xyz
# 文件已重命名为 moa3_mob4.xyz
# 文件已重命名为 moa3_mob5.xyz
# 文件已重命名为 moa3_mob6.xyz
# 文件已重命名为 moa3_mob7.xyz
# 文件已重命名为 moa3_mob8.xyz
# 文件已重命名为 moa3_mob9.xyz
# 文件已重命名为 moa3_mob10.xyz
# 文件已重命名为 moa3_mob11.xyz
# 文件已重命名为 moa3_mob12.xyz
# 文件已重命名为 moa3_mob13.xyz
# 文件已重命名为 moa3_mob14.xyz
# 文件已重命名为 moa3_mob15.xyz
# 文件已重命名为 moa3_mob16.xyz
# 文件已重命名为 moa3_mob17.xyz
# 文件已重命名为 moa3_mob18.xyz
# 文件已重命名为 moa3_mob19.xyz
# 文件已重命名为 moa3_mob20.xyz
# 文件已重命名为 moa3_mob21.xyz
# 文件已重命名为 moa4_mob1.xyz
# 文件已重命名为 moa4_mob2.xyz
# 文件已重命名为 moa4_mob3.xyz
# 文件已重命名为 moa4_mob4.xyz
# 文件已重命名为 moa4_mob5.xyz
# 文件已重命名为 moa4_mob6.xyz
# 文件已重命名为 moa4_mob7.xyz
# 文件已重命名为 moa4_mob8.xyz
# 文件已重命名为 moa4_mob9.xyz
# 文件已重命名为 moa4_mob10.xyz
# 文件已重命名为 moa4_mob11.xyz
# 文件已重命名为 moa4_mob12.xyz
# 文件已重命名为 moa4_mob13.xyz
# 文件已重命名为 moa4_mob14.xyz
# 文件已重命名为 moa4_mob15.xyz
# 文件已重命名为 moa4_mob16.xyz
# 文件已重命名为 moa4_mob17.xyz
# 文件已重命名为 moa4_mob18.xyz
# 文件已重命名为 moa4_mob19.xyz
# 文件已重命名为 moa4_mob20.xyz
# 文件已重命名为 moa4_mob21.xyz
# 文件已重命名为 moa5_mob1.xyz
# 文件已重命名为 moa5_mob2.xyz
# 文件已重命名为 moa5_mob3.xyz
# 文件已重命名为 moa5_mob4.xyz
# 文件已重命名为 moa5_mob5.xyz
# 文件已重命名为 moa5_mob6.xyz
# 文件已重命名为 moa5_mob7.xyz
# 文件已重命名为 moa5_mob8.xyz
# 文件已重命名为 moa5_mob9.xyz
# 文件已重命名为 moa5_mob10.xyz
# 文件已重命名为 moa5_mob11.xyz
# 文件已重命名为 moa5_mob12.xyz
# 文件已重命名为 moa5_mob13.xyz
# 文件已重命名为 moa5_mob14.xyz
# 文件已重命名为 moa5_mob15.xyz
# 文件已重命名为 moa5_mob16.xyz
# 文件已重命名为 moa5_mob17.xyz
# 文件已重命名为 moa5_mob18.xyz
# 文件已重命名为 moa5_mob19.xyz
# 文件已重命名为 moa5_mob20.xyz
# 文件已重命名为 moa5_mob21.xyz
# 文件已重命名为 moa6_mob1.xyz
# 文件已重命名为 moa6_mob2.xyz
# 文件已重命名为 moa6_mob3.xyz
# 文件已重命名为 moa6_mob4.xyz
# 文件已重命名为 moa6_mob5.xyz
# 文件已重命名为 moa6_mob6.xyz
# 文件已重命名为 moa6_mob7.xyz
# 文件已重命名为 moa6_mob8.xyz
# 文件已重命名为 moa6_mob9.xyz
# 文件已重命名为 moa6_mob10.xyz
# 文件已重命名为 moa6_mob11.xyz
# 文件已重命名为 moa6_mob12.xyz
# 文件已重命名为 moa6_mob13.xyz
# 文件已重命名为 moa6_mob14.xyz
# 文件已重命名为 moa6_mob15.xyz
# 文件已重命名为 moa6_mob16.xyz
# 文件已重命名为 moa6_mob17.xyz
# 文件已重命名为 moa6_mob18.xyz
# 文件已重命名为 moa6_mob19.xyz
# 文件已重命名为 moa6_mob20.xyz
# 文件已重命名为 moa6_mob21.xyz
# 文件已重命名为 moa7_mob1.xyz
# 文件已重命名为 moa7_mob2.xyz
# 文件已重命名为 moa7_mob3.xyz
# 文件已重命名为 moa7_mob4.xyz
# 文件已重命名为 moa7_mob5.xyz
# 文件已重命名为 moa7_mob6.xyz
# 文件已重命名为 moa7_mob7.xyz
# 文件已重命名为 moa7_mob8.xyz
# 文件已重命名为 moa7_mob9.xyz
# 文件已重命名为 moa7_mob10.xyz
# 文件已重命名为 moa7_mob11.xyz
# 文件已重命名为 moa7_mob12.xyz
# 文件已重命名为 moa7_mob13.xyz
# 文件已重命名为 moa7_mob14.xyz
# 文件已重命名为 moa7_mob15.xyz
# 文件已重命名为 moa7_mob16.xyz
# 文件已重命名为 moa7_mob17.xyz
# 文件已重命名为 moa7_mob18.xyz
# 文件已重命名为 moa7_mob19.xyz
# 文件已重命名为 moa7_mob20.xyz
# 文件已重命名为 moa7_mob21.xyz
# 文件已重命名为 moa8_mob1.xyz
# 文件已重命名为 moa8_mob2.xyz
# 文件已重命名为 moa8_mob3.xyz
# 文件已重命名为 moa8_mob4.xyz
# 文件已重命名为 moa8_mob5.xyz
# 文件已重命名为 moa8_mob6.xyz
# 文件已重命名为 moa8_mob7.xyz
# 文件已重命名为 moa8_mob8.xyz
# 文件已重命名为 moa8_mob9.xyz
# 文件已重命名为 moa8_mob10.xyz
# 文件已重命名为 moa8_mob11.xyz
# 文件已重命名为 moa8_mob12.xyz
# 文件已重命名为 moa8_mob13.xyz
# 文件已重命名为 moa8_mob14.xyz
# 文件已重命名为 moa8_mob15.xyz
# 文件已重命名为 moa8_mob16.xyz
# 文件已重命名为 moa8_mob17.xyz
# 文件已重命名为 moa8_mob18.xyz
# 文件已重命名为 moa8_mob19.xyz
# 文件已重命名为 moa8_mob20.xyz
# 文件已重命名为 moa8_mob21.xyz
# 文件已重命名为 moa9_mob1.xyz
# 文件已重命名为 moa9_mob2.xyz
# 文件已重命名为 moa9_mob3.xyz
# 文件已重命名为 moa9_mob4.xyz
# 文件已重命名为 moa9_mob5.xyz
# 文件已重命名为 moa9_mob6.xyz
# 文件已重命名为 moa9_mob7.xyz
# 文件已重命名为 moa9_mob8.xyz
# 文件已重命名为 moa9_mob9.xyz
# 文件已重命名为 moa9_mob10.xyz
# 文件已重命名为 moa9_mob11.xyz
# 文件已重命名为 moa9_mob12.xyz
# 文件已重命名为 moa9_mob13.xyz
# 文件已重命名为 moa9_mob14.xyz
# 文件已重命名为 moa9_mob15.xyz
# 文件已重命名为 moa9_mob16.xyz
# 文件已重命名为 moa9_mob17.xyz
# 文件已重命名为 moa9_mob18.xyz
# 文件已重命名为 moa9_mob19.xyz
# 文件已重命名为 moa9_mob20.xyz
# 文件已重命名为 moa9_mob21.xyz
# 文件已重命名为 moa10_mob1.xyz
# 文件已重命名为 moa10_mob2.xyz
# 文件已重命名为 moa10_mob3.xyz
# 文件已重命名为 moa10_mob4.xyz
# 文件已重命名为 moa10_mob5.xyz
# 文件已重命名为 moa10_mob6.xyz
# 文件已重命名为 moa10_mob7.xyz
# 文件已重命名为 moa10_mob8.xyz
# 文件已重命名为 moa10_mob9.xyz
# 文件已重命名为 moa10_mob10.xyz
# 文件已重命名为 moa10_mob11.xyz
# 文件已重命名为 moa10_mob12.xyz
# 文件已重命名为 moa10_mob13.xyz
# 文件已重命名为 moa10_mob14.xyz
# 文件已重命名为 moa10_mob15.xyz
# 文件已重命名为 moa10_mob16.xyz
# 文件已重命名为 moa10_mob17.xyz
# 文件已重命名为 moa10_mob18.xyz
# 文件已重命名为 moa10_mob19.xyz
# 文件已重命名为 moa10_mob20.xyz
# 文件已重命名为 moa10_mob21.xyz
# 文件已重命名为 moa11_mob1.xyz
# 文件已重命名为 moa11_mob2.xyz
# 文件已重命名为 moa11_mob3.xyz
# 文件已重命名为 moa11_mob4.xyz
# 文件已重命名为 moa11_mob5.xyz
# 文件已重命名为 moa11_mob6.xyz
# 文件已重命名为 moa11_mob7.xyz
# 文件已重命名为 moa11_mob8.xyz
# 文件已重命名为 moa11_mob9.xyz
# 文件已重命名为 moa11_mob10.xyz
# 文件已重命名为 moa11_mob11.xyz
# 文件已重命名为 moa11_mob12.xyz
# 文件已重命名为 moa11_mob13.xyz
# 文件已重命名为 moa11_mob14.xyz
# 文件已重命名为 moa11_mob15.xyz
# 文件已重命名为 moa11_mob16.xyz
# 文件已重命名为 moa11_mob17.xyz
# 文件已重命名为 moa11_mob18.xyz
# 文件已重命名为 moa11_mob19.xyz
# 文件已重命名为 moa11_mob20.xyz
# 文件已重命名为 moa11_mob21.xyz
# 文件已重命名为 moa12_mob1.xyz
# 文件已重命名为 moa12_mob2.xyz
# 文件已重命名为 moa12_mob3.xyz
# 文件已重命名为 moa12_mob4.xyz
# 文件已重命名为 moa12_mob5.xyz
# 文件已重命名为 moa12_mob6.xyz
# 文件已重命名为 moa12_mob7.xyz
# 文件已重命名为 moa12_mob8.xyz
# 文件已重命名为 moa12_mob9.xyz
# 文件已重命名为 moa12_mob10.xyz
# 文件已重命名为 moa12_mob11.xyz
# 文件已重命名为 moa12_mob12.xyz
# 文件已重命名为 moa12_mob13.xyz
# 文件已重命名为 moa12_mob14.xyz
# 文件已重命名为 moa12_mob15.xyz
# 文件已重命名为 moa12_mob16.xyz
# 文件已重命名为 moa12_mob17.xyz
# 文件已重命名为 moa12_mob18.xyz
# 文件已重命名为 moa12_mob19.xyz
# 文件已重命名为 moa12_mob20.xyz
# 文件已重命名为 moa12_mob21.xyz
# 文件已重命名为 moa13_mob1.xyz
# 文件已重命名为 moa13_mob2.xyz
# 文件已重命名为 moa13_mob3.xyz
# 文件已重命名为 moa13_mob4.xyz
# 文件已重命名为 moa13_mob5.xyz
# 文件已重命名为 moa13_mob6.xyz
# 文件已重命名为 moa13_mob7.xyz
# 文件已重命名为 moa13_mob8.xyz
# 文件已重命名为 moa13_mob9.xyz
# 文件已重命名为 moa13_mob10.xyz
# 文件已重命名为 moa13_mob11.xyz
# 文件已重命名为 moa13_mob12.xyz
# 文件已重命名为 moa13_mob13.xyz
# 文件已重命名为 moa13_mob14.xyz
# 文件已重命名为 moa13_mob15.xyz
# 文件已重命名为 moa13_mob16.xyz
# 文件已重命名为 moa13_mob17.xyz
# 文件已重命名为 moa13_mob18.xyz
# 文件已重命名为 moa13_mob19.xyz
# 文件已重命名为 moa13_mob20.xyz
# 文件已重命名为 moa13_mob21.xyz
# 文件已重命名为 moa14_mob1.xyz
# 文件已重命名为 moa14_mob2.xyz
# 文件已重命名为 moa14_mob3.xyz
# 文件已重命名为 moa14_mob4.xyz
# 文件已重命名为 moa14_mob5.xyz
# 文件已重命名为 moa14_mob6.xyz
# 文件已重命名为 moa14_mob7.xyz
# 文件已重命名为 moa14_mob8.xyz
# 文件已重命名为 moa14_mob9.xyz
# 文件已重命名为 moa14_mob10.xyz
# 文件已重命名为 moa14_mob11.xyz
# 文件已重命名为 moa14_mob12.xyz
# 文件已重命名为 moa14_mob13.xyz
# 文件已重命名为 moa14_mob14.xyz
# 文件已重命名为 moa14_mob15.xyz
# 文件已重命名为 moa14_mob16.xyz
# 文件已重命名为 moa14_mob17.xyz
# 文件已重命名为 moa14_mob18.xyz
# 文件已重命名为 moa14_mob19.xyz
# 文件已重命名为 moa14_mob20.xyz
# 文件已重命名为 moa14_mob21.xyz
# 文件已重命名为 moa15_mob1.xyz
# 文件已重命名为 moa15_mob2.xyz
# 文件已重命名为 moa15_mob3.xyz
# 文件已重命名为 moa15_mob4.xyz
# 文件已重命名为 moa15_mob5.xyz
# 文件已重命名为 moa15_mob6.xyz
# 文件已重命名为 moa15_mob7.xyz
# 文件已重命名为 moa15_mob8.xyz
# 文件已重命名为 moa15_mob9.xyz
# 文件已重命名为 moa15_mob10.xyz
# 文件已重命名为 moa15_mob11.xyz
# 文件已重命名为 moa15_mob12.xyz
# 文件已重命名为 moa15_mob13.xyz
# 文件已重命名为 moa15_mob14.xyz
# 文件已重命名为 moa15_mob15.xyz
# 文件已重命名为 moa15_mob16.xyz
# 文件已重命名为 moa15_mob17.xyz
# 文件已重命名为 moa15_mob18.xyz
# 文件已重命名为 moa15_mob19.xyz
# 文件已重命名为 moa15_mob20.xyz
# 文件已重命名为 moa15_mob21.xyz
# 文件已重命名为 moa16_mob1.xyz
# 文件已重命名为 moa16_mob2.xyz
# 文件已重命名为 moa16_mob3.xyz
# 文件已重命名为 moa16_mob4.xyz
# 文件已重命名为 moa16_mob5.xyz
# 文件已重命名为 moa16_mob6.xyz
# 文件已重命名为 moa16_mob7.xyz
# 文件已重命名为 moa16_mob8.xyz
# 文件已重命名为 moa16_mob9.xyz
# 文件已重命名为 moa16_mob10.xyz
# 文件已重命名为 moa16_mob11.xyz
# 文件已重命名为 moa16_mob12.xyz
# 文件已重命名为 moa16_mob13.xyz
# 文件已重命名为 moa16_mob14.xyz
# 文件已重命名为 moa16_mob15.xyz
# 文件已重命名为 moa16_mob16.xyz
# 文件已重命名为 moa16_mob17.xyz
# 文件已重命名为 moa16_mob18.xyz
# 文件已重命名为 moa16_mob19.xyz
# 文件已重命名为 moa16_mob20.xyz
# 文件已重命名为 moa16_mob21.xyz
# 文件已重命名为 moa17_mob1.xyz
# 文件已重命名为 moa17_mob2.xyz
# 文件已重命名为 moa17_mob3.xyz
# 文件已重命名为 moa17_mob4.xyz
# 文件已重命名为 moa17_mob5.xyz
# 文件已重命名为 moa17_mob6.xyz
# 文件已重命名为 moa17_mob7.xyz
# 文件已重命名为 moa17_mob8.xyz
# 文件已重命名为 moa17_mob9.xyz
# 文件已重命名为 moa17_mob10.xyz
# 文件已重命名为 moa17_mob11.xyz
# 文件已重命名为 moa17_mob12.xyz
# 文件已重命名为 moa17_mob13.xyz
# 文件已重命名为 moa17_mob14.xyz
# 文件已重命名为 moa17_mob15.xyz
# 文件已重命名为 moa17_mob16.xyz
# 文件已重命名为 moa17_mob17.xyz
# 文件已重命名为 moa17_mob18.xyz
# 文件已重命名为 moa17_mob19.xyz
# 文件已重命名为 moa17_mob20.xyz
# 文件已重命名为 moa17_mob21.xyz
# 文件已重命名为 moa18_mob1.xyz
# 文件已重命名为 moa18_mob2.xyz
# 文件已重命名为 moa18_mob3.xyz
# 文件已重命名为 moa18_mob4.xyz
# 文件已重命名为 moa18_mob5.xyz
# 文件已重命名为 moa18_mob6.xyz
# 文件已重命名为 moa18_mob7.xyz
# 文件已重命名为 moa18_mob8.xyz
# 文件已重命名为 moa18_mob9.xyz
# 文件已重命名为 moa18_mob10.xyz
# 文件已重命名为 moa18_mob11.xyz
# 文件已重命名为 moa18_mob12.xyz
# 文件已重命名为 moa18_mob13.xyz
# 文件已重命名为 moa18_mob14.xyz
# 文件已重命名为 moa18_mob15.xyz
# 文件已重命名为 moa18_mob16.xyz
# 文件已重命名为 moa18_mob17.xyz
# 文件已重命名为 moa18_mob18.xyz
# 文件已重命名为 moa18_mob19.xyz
# 文件已重命名为 moa18_mob20.xyz
# 文件已重命名为 moa18_mob21.xyz
# 文件已重命名为 moa19_mob1.xyz
# 文件已重命名为 moa19_mob2.xyz
# 文件已重命名为 moa19_mob3.xyz
# 文件已重命名为 moa19_mob4.xyz
# 文件已重命名为 moa19_mob5.xyz
# 文件已重命名为 moa19_mob6.xyz
# 文件已重命名为 moa19_mob7.xyz
# 文件已重命名为 moa19_mob8.xyz
# 文件已重命名为 moa19_mob9.xyz
# 文件已重命名为 moa19_mob10.xyz
# 文件已重命名为 moa19_mob11.xyz
# 文件已重命名为 moa19_mob12.xyz
# 文件已重命名为 moa19_mob13.xyz
# 文件已重命名为 moa19_mob14.xyz
# 文件已重命名为 moa19_mob15.xyz
# 文件已重命名为 moa19_mob16.xyz
# 文件已重命名为 moa19_mob17.xyz
# 文件已重命名为 moa19_mob18.xyz
# 文件已重命名为 moa19_mob19.xyz
# 文件已重命名为 moa19_mob20.xyz
# 文件已重命名为 moa19_mob21.xyz
# 文件已重命名为 moa20_mob1.xyz
# 文件已重命名为 moa20_mob2.xyz
# 文件已重命名为 moa20_mob3.xyz
# 文件已重命名为 moa20_mob4.xyz
# 文件已重命名为 moa20_mob5.xyz
# 文件已重命名为 moa20_mob6.xyz
# 文件已重命名为 moa20_mob7.xyz
# 文件已重命名为 moa20_mob8.xyz
# 文件已重命名为 moa20_mob9.xyz
# 文件已重命名为 moa20_mob10.xyz
# 文件已重命名为 moa20_mob11.xyz
# 文件已重命名为 moa20_mob12.xyz
# 文件已重命名为 moa20_mob13.xyz
# 文件已重命名为 moa20_mob14.xyz
# 文件已重命名为 moa20_mob15.xyz
# 文件已重命名为 moa20_mob16.xyz
# 文件已重命名为 moa20_mob17.xyz
# 文件已重命名为 moa20_mob18.xyz
# 文件已重命名为 moa20_mob19.xyz
# 文件已重命名为 moa20_mob20.xyz
# 文件已重命名为 moa20_mob21.xyz
# 文件已重命名为 moa21_mob1.xyz
# 文件已重命名为 moa21_mob2.xyz
# 文件已重命名为 moa21_mob3.xyz
# 文件已重命名为 moa21_mob4.xyz
# 文件已重命名为 moa21_mob5.xyz
# 文件已重命名为 moa21_mob6.xyz
# 文件已重命名为 moa21_mob7.xyz
# 文件已重命名为 moa21_mob8.xyz
# 文件已重命名为 moa21_mob9.xyz
# 文件已重命名为 moa21_mob10.xyz
# 文件已重命名为 moa21_mob11.xyz
# 文件已重命名为 moa21_mob12.xyz
# 文件已重命名为 moa21_mob13.xyz
# 文件已重命名为 moa21_mob14.xyz
# 文件已重命名为 moa21_mob15.xyz
# 文件已重命名为 moa21_mob16.xyz
# 文件已重命名为 moa21_mob17.xyz
# 文件已重命名为 moa21_mob18.xyz
# 文件已重命名为 moa21_mob19.xyz
# 文件已重命名为 moa21_mob20.xyz
# 文件已重命名为 moa21_mob21.xyz
